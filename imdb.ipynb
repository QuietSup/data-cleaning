# %%
import pandas as pd
import numpy as np
import re
from pycountry import countries

# %%
imdb = pd.read_csv('messy_IMDB_dataset.csv', delimiter=';', encoding='latin1')
imdb
# Out:
#     IMBD title ID               Original titlÊ  Release year  \
# 0       tt0111161     The Shawshank Redemption    1995-02-10
# 1       tt0068646                The Godfather    09 21 1972
# 2       tt0468569              The Dark Knight   23 -07-2008
# 3       tt0071562       The Godfather: Part II    1975-09-25
# 4       tt0110912                 Pulp Fiction    1994-10-28
# ..            ...                          ...           ...
# 96      tt0070735                    The Sting    1974-03-21
# 97      tt0082096                     Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
# check if the column is redurant
if imdb['Unnamed: 8'].isna().any():
    imdb.drop(columns=['Unnamed: 8'], inplace=True)
imdb
# Out:
#     IMBD title ID               Original titlÊ  Release year  \
# 0       tt0111161     The Shawshank Redemption    1995-02-10
# 1       tt0068646                The Godfather    09 21 1972
# 2       tt0468569              The Dark Knight   23 -07-2008
# 3       tt0071562       The Godfather: Part II    1975-09-25
# 4       tt0110912                 Pulp Fiction    1994-10-28
# ..            ...                          ...           ...
# 96      tt0070735                    The Sting    1974-03-21
# 97      tt0082096                     Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
imdb.rename(columns={
    'IMBD title ID': 'title ID',
    'Original titlÊ': 'Original title',
    'Genrë¨': 'Genre',
    ' Votes ': 'Votes',
}, inplace=True)

# change columns' headers
imdb.columns
# Out:
# Index(['title ID', 'Original title', 'Release year', 'Genre', 'Duration',
#        'Country', 'Content Rating', 'Director', 'Income', 'Votes', 'Score'],
#       dtype='object')

# %%
imdb.dtypes
# Out:
# title ID          object
# Original title    object
# Release year      object
# Genre             object
# Duration          object
# Country           object
# Content Rating    object
# Director          object
# Income            object
# Votes             object
# Score             object
# dtype: object

# %%
# check if each id has 9 symbols
imdb[imdb['title ID'].str.len() != 9]
# Out:
#    title ID Original title Release year Genre Duration Country Content Rating  \
# 13      NaN            NaN          NaN   NaN      NaN     NaN            NaN
#
#    Director Income Votes Score
# 13      NaN    NaN   NaN   NaN

# %%
# all the row has NaN values, so let's remove it
imdb.drop(index=13, inplace=True)

# %%
# if `Release year` contains anything exept nubers, spaes and `-`
imdb[imdb['Release year'].str.contains(r'[^\d\w-]', regex=True)]
# Out:
#      title ID                                 Original title  \
# 1   tt0068646                                  The Godfather
# 2   tt0468569                                The Dark Knight
# 5   tt0167260  The Lord of the Rings: The Return of the King
# 12  tt0060196                Il buono, il brutto, il cattivo
# 15  tt0167261          The Lord of the Rings: The Two Towers
# 18  tt0073486                One Flew Over the Cuckoo's Nest
# 70  tt0043014                                   Sunset Blvd.
#
#                    Release year                     Genre Duration  \
# 1                    09 21 1972              Crime, Drama      175
# 2                   23 -07-2008      Action, Crime, Drama      152
# 5                     22 Feb 04  Action, Adventure, Drama      201
# 12       23rd December of 1966                    Western      161
# 15                     01/16-03  Action, Adventure, Drama      179
# 18                   18/11/1976                     Drama        -
# ...

# %%
# if `Release year` contains numbers which can't be relevant to a date
imdb[imdb['Release year'].str.contains(r'([^\d]|^)([\d]{1}|[\d]{3}|[\d]{5,})[^\d]', regex=True)]
# Out:
# C:\Users\38098\AppData\Local\Temp\ipykernel_15996\405385419.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   imdb[imdb['Release year'].str.contains(r'([^\d]|^)([\d]{1}|[\d]{3}|[\d]{5,})[^\d]', regex=True)]
#      title ID Original title                 Release year             Genre  \
# 70  tt0043014   Sunset Blvd.  The 6th of marzo, year 1951  Drama, Film-Noir
#
#    Duration Country Content Rating      Director    Income    Votes Score
# 70      110     USA            NaN  Billy Wilder  $ 299645  195.789   8.0

# %%
# we don't know what 6 means, so let's just set the cell to None
imdb.at[70, 'Release year'] = None
imdb.loc[[70]]
# Out:
#      title ID Original title Release year             Genre Duration Country  \
# 70  tt0043014   Sunset Blvd.         None  Drama, Film-Noir      110     USA
#
#    Content Rating      Director    Income    Votes Score
# 70            NaN  Billy Wilder  $ 299645  195.789   8.0

# %%
# remove spaces and other redurant symbols from the data
# imdb['Release year'].replace(r'[^A-Za-z\d]+', '-', regex=True, inplace=True)
# imdb['Release year'].replace(r'^[^A-Za-z\d]+|[^A-Za-z\d]+$', '', regex=True, inplace=True)
imdb
# Out:
#       title ID               Original title  Release year  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10
# 1    tt0068646                The Godfather    09 21 1972
# 2    tt0468569              The Dark Knight   23 -07-2008
# 3    tt0071562       The Godfather: Part II    1975-09-25
# 4    tt0110912                 Pulp Fiction    1994-10-28
# ..         ...                          ...           ...
# 96   tt0070735                    The Sting    1974-03-21
# 97   tt0082096                     Das Boot    1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100  tt0045152          Singin' in the Rain    1953-02-05
#
#                           Genre Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
# function for the time conversion
def fix_date(date_str):
    if not date_str:
        return date_str
    
    numbers = re.findall(r'\b\d{1,4}(?=(?:st|nd|rd|th)\b)?', date_str)
    word = re.findall(r'\b(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?)\b', date_str, flags=re.IGNORECASE)
    r = '-'.join(numbers)
    if word:
        r = r + '-' + word[0]
    return r

imdb['Release year'] = imdb['Release year'].apply(fix_date)

imdb['Release year'] = pd.to_datetime(imdb['Release year'], errors='coerce', format='mixed')
# imdb['Release year'].apply(lambda x: pd.to_datetime(x).strftime('%m/%d/%Y')[0])
# imdb['Release year'].apply()
# imdb['Release year'] = pd.to_datetime(imdb['Release year'], format='%d %b %y')
# imdb['Release year'] = pd.to_datetime(imdb['Release year'], format='%Y-%m-%d')
imdb['Release year']
# Out:
# 0     1995-02-10
# 1     1972-09-21
# 2     2008-07-23
# 3     1975-09-25
# 4     1994-10-28
#          ...
# 96    1974-03-21
# 97    1982-03-18
# 98    1965-12-20
# 99    2011-10-21
# 100   1953-02-05
# Name: Release year, Length: 100, dtype: datetime64[ns]

# %%
# find duplicated id
imdb[imdb.duplicated(['title ID'])]
# Out:
# Empty DataFrame
# Columns: [title ID, Original title, Release year, Genre, Duration, Country, Content Rating, Director, Income, Votes, Score]
# Index: []

# %%
imdb['Country'].isin(countries).value_counts()
# Out:
# Country
# False    100
# Name: count, dtype: int64

# %%
def iscountry(name):
    try:
        countries.lookup(name)
    except(LookupError):
        return False
    else:
        return True

countries_errors = imdb['Country'].apply(lambda x: not iscountry(x))
imdb[countries_errors]['Country']
# Out:
# 9               UK
# 11     New Zesland
# 15      New Zeland
# 24             US.
# 27          Italy1
# 33              UK
# 42              UK
# 50              UK
# 54              UK
# 57              UK
# 61              UK
# 79              UK
# 81              UK
# 86              UK
# 88              UK
# 95              UK
# 97    West Germany
# 99            Iran
# Name: Country, dtype: object

# %%
# edit countries names
imdb.loc[imdb['Country'] == 'Italy1', 'Country'] = 'Italy'
imdb.loc[imdb['Country'].str.contains('New Z'), 'Country'] = 'New Zealand'
imdb.loc[imdb['Country'].str.contains('US'), 'Country'] = 'USA'
imdb
# Out:
#       title ID               Original title Release year  \
# 0    tt0111161     The Shawshank Redemption   1995-02-10
# 1    tt0068646                The Godfather   1972-09-21
# 2    tt0468569              The Dark Knight   2008-07-23
# 3    tt0071562       The Godfather: Part II   1975-09-25
# 4    tt0110912                 Pulp Fiction   1994-10-28
# ..         ...                          ...          ...
# 96   tt0070735                    The Sting   1974-03-21
# 97   tt0082096                     Das Boot   1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹   1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin   2011-10-21
# 100  tt0045152          Singin' in the Rain   1953-02-05
#
#                           Genre Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
# check duration digits
# imdb.loc[imdb['Duration'].isna(), 'Duration'] = None
imdb[
    ~(imdb['Duration'].isnull() | imdb['Duration'].str.isdecimal())
    ]['Duration']
# Out:
# 4
# 6                Nan
# 9                Inf
# 11              178c
# 16    Not Applicable
# 18                 -
# Name: Duration, dtype: object

# %%
# edit duration
imdb['Duration'] = imdb['Duration'].str.replace(r'[^\d]+', '', regex=True)
imdb['Duration'] = pd.to_numeric(imdb['Duration'], errors='coerce', downcast='integer')
imdb
# Out:
#       title ID               Original title Release year  \
# 0    tt0111161     The Shawshank Redemption   1995-02-10
# 1    tt0068646                The Godfather   1972-09-21
# 2    tt0468569              The Dark Knight   2008-07-23
# 3    tt0071562       The Godfather: Part II   1975-09-25
# 4    tt0110912                 Pulp Fiction   1994-10-28
# ..         ...                          ...          ...
# 96   tt0070735                    The Sting   1974-03-21
# 97   tt0082096                     Das Boot   1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹   1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin   2011-10-21
# 100  tt0045152          Singin' in the Rain   1953-02-05
#
#                           Genre  Duration       Country Content Rating  \
# 0                         Drama     142.0           USA              R
# 1                  Crime, Drama     175.0           USA              R
# ...

# %%
# income check
imdb['Income'] = imdb['Income'].str.strip()
imdb['Income'] = imdb['Income'].str.strip('$')
imdb['Income'] = imdb['Income'].str.strip(',')
imdb[~(imdb['Income'].isnull() | imdb['Income'].str.isdecimal())]['Income']
# Out:
# 0          28815245
# 1         246120974
# 2        1005455211
# 3       4o8,035,783
# 4         222831817
#            ...
# 96        156000000
# 97         11487676
# 98         15000000
# 99         22926076
# 100         1864182
# Name: Income, Length: 100, dtype: object

# %%
imdb['Income'] = imdb['Income'].str.replace('o', '0')
imdb['Income'] = pd.to_numeric(imdb['Income'], errors='coerce', downcast='integer')
imdb
# Out:
#       title ID               Original title Release year  \
# 0    tt0111161     The Shawshank Redemption   1995-02-10
# 1    tt0068646                The Godfather   1972-09-21
# 2    tt0468569              The Dark Knight   2008-07-23
# 3    tt0071562       The Godfather: Part II   1975-09-25
# 4    tt0110912                 Pulp Fiction   1994-10-28
# ..         ...                          ...          ...
# 96   tt0070735                    The Sting   1974-03-21
# 97   tt0082096                     Das Boot   1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹   1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin   2011-10-21
# 100  tt0045152          Singin' in the Rain   1953-02-05
#
#                           Genre  Duration       Country Content Rating  \
# 0                         Drama     142.0           USA              R
# 1                  Crime, Drama     175.0           USA              R
# ...

# %%
# income check
imdb['Votes'] = imdb['Votes'].str.strip()
imdb['Votes'] = imdb['Votes'].str.replace('.', '')
imdb[~(imdb['Votes'].isnull() | imdb['Votes'].str.isdecimal())]['Votes']
# Out:
# Series([], Name: Votes, dtype: object)

# %%
# convert votes to float
imdb['Votes'] = pd.to_numeric(imdb['Votes'], errors='coerce')

# %%
# check scores
imdb[~imdb['Score'].str.contains(r'^\d{1,2}.\d$')]['Score']
# Out:
# 2         9.
# 3       9,.0
# 4       8,9f
# 8       8..8
# 14     ++8.7
# 15      8.7.
# 16    8,7e-0
# Name: Score, dtype: object

# %%
imdb['Score'] = imdb['Score'].str.replace(r'[.,]+\b', '.', regex=True)
imdb['Score'] = imdb['Score'].str.replace(r'[^\d.,]', '', regex=True)
imdb['Score'] = imdb['Score'].str.strip('.')
imdb[~imdb['Score'].str.contains(r'^\d{1,2}.\d$')]['Score']
# Out:
# 2        9
# 10      88
# 16    8.70
# Name: Score, dtype: object

# %%
imdb['Score'] = pd.to_numeric(imdb['Score'], errors='coerce')
imdb.dtypes
# Out:
# title ID                  object
# Original title            object
# Release year      datetime64[ns]
# Genre                     object
# Duration                 float64
# Country                   object
# Content Rating            object
# Director                  object
# Income                   float64
# Votes                      int64
# Score                    float64
# dtype: object

# %%
# check if all scores are less than 10.0
imdb[(imdb['Score'] > 10.) | (imdb['Score']< 0.)]
# Out:
#      title ID Original title Release year           Genre  Duration Country  \
# 10  tt0109830   Forrest Gump   1994-10-06  Drama, Romance     142.0     USA
#
#    Content Rating         Director       Income    Votes  Score
# 10          PG-13  Robert Zemeckis  678229452.0  1755490   88.0

# %%
imdb['Score'] = imdb['Score'].apply(lambda x: x/10 if x > 10 else x)
imdb[(imdb['Score'] > 10.) | (imdb['Score']< 0.)]
# Out:
# Empty DataFrame
# Columns: [title ID, Original title, Release year, Genre, Duration, Country, Content Rating, Director, Income, Votes, Score]
# Index: []

# %%
imdb.dtypes
# Out:
# title ID                  object
# Original title            object
# Release year      datetime64[ns]
# Genre                     object
# Duration                 float64
# Country                   object
# Content Rating            object
# Director                  object
# Income                   float64
# Votes                      int64
# Score                    float64
# dtype: object

# %%
imdb
# Out:
#       title ID               Original title Release year  \
# 0    tt0111161     The Shawshank Redemption   1995-02-10
# 1    tt0068646                The Godfather   1972-09-21
# 2    tt0468569              The Dark Knight   2008-07-23
# 3    tt0071562       The Godfather: Part II   1975-09-25
# 4    tt0110912                 Pulp Fiction   1994-10-28
# ..         ...                          ...          ...
# 96   tt0070735                    The Sting   1974-03-21
# 97   tt0082096                     Das Boot   1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹   1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin   2011-10-21
# 100  tt0045152          Singin' in the Rain   1953-02-05
#
#                           Genre  Duration       Country Content Rating  \
# 0                         Drama     142.0           USA              R
# 1                  Crime, Drama     175.0           USA              R
# ...

# %%
imdb['id'] = imdb.index
movie_genre = pd.DataFrame({'movie_id': imdb.index, 'genre': imdb['Genre']})

movie_genre['genre'] = movie_genre['genre'].apply(lambda x: x.replace(' ', '').split(','))
movie_genre = movie_genre.explode('genre')
movie_genre
# Out:
#      movie_id    genre
# 0           0    Drama
# 1           1    Crime
# 1           1    Drama
# 2           2   Action
# 2           2    Crime
# ..        ...      ...
# 98         98  Western
# 99         99    Drama
# 100       100   Comedy
# 100       100  Musical
# 100       100  Romance
#
# [245 rows x 2 columns]

# %%
# spliting genres to rows
genres = pd.DataFrame(
    {'genre_name': movie_genre['genre'].unique(),}
)
genres['id'] = np.arange(0, genres['genre_name'].count())
genres
# Out:
#    genre_name  id
# 0       Drama   0
# 1       Crime   1
# 2      Action   2
# 3   Adventure   3
# 4   Biography   4
# 5     History   5
# 6      Sci-Fi   6
# 7     Romance   7
# 8     Western   8
# 9     Fantasy   9
# 10    Mystery  10
# 11   Thriller  11
# 12        War  12
# 13  Animation  13
# 14     Family  14
# 15     Comedy  15
# 16      Music  16
# 17     Horror  17
# 18  Film-Noir  18
# 19    Musical  19

# %%
movie_genre['genre'] = movie_genre['genre'].apply(lambda x: genres.index[genres['genre_name'] == x][0])
movie_genre.rename(columns={'genre': 'genre_id'}, inplace=True)
imdb.drop(columns='Genre', inplace=True)
movie_genre
# Out:
#      movie_id  genre_id
# 0           0         0
# 1           1         1
# 1           1         0
# 2           2         2
# 2           2         1
# ..        ...       ...
# 98         98         8
# 99         99         0
# 100       100        15
# 100       100        19
# 100       100         7
#
# [245 rows x 2 columns]

# %%
# handling `Director` column
movie_director = pd.DataFrame({'movie_id': imdb['id'], 'directors': imdb['Director']})
imdb.drop(columns='Director', inplace=True)
movie_director['directors'] = movie_director['directors'].apply(lambda x: [xi.strip() for xi in x.split(',')])
movie_director = movie_director.explode('directors')
movie_director
# Out:
#      movie_id             directors
# 0           0        Frank Darabont
# 1           1  Francis Ford Coppola
# 2           2     Christopher Nolan
# 3           3  Francis Ford Coppola
# 4           4     Quentin Tarantino
# ..        ...                   ...
# 96         96       George Roy Hill
# 97         97     Wolfgang Petersen
# 98         98          Sergio Leone
# 99         99        Asghar Farhadi
# 100       100         Stanley Donen
#
# [108 rows x 2 columns]

# %%
# create frame with data about directors
directors = pd.DataFrame({'director': movie_director['directors'].unique()})
directors['id'] = np.arange(0, directors['director'].count())
directors
# Out:
#                 director  id
# 0         Frank Darabont   0
# 1   Francis Ford Coppola   1
# 2      Christopher Nolan   2
# 3      Quentin Tarantino   3
# 4          Peter Jackson   4
# ..                   ...  ..
# 65            David Lean  65
# 66       George Roy Hill  66
# 67     Wolfgang Petersen  67
# 68        Asghar Farhadi  68
# 69         Stanley Donen  69
#
# [70 rows x 2 columns]

# %%
directors.dtypes
# Out:
# director    object
# id           int64
# dtype: object

# %%
# find if there is any non-alphabet character
directors[directors['director'].str.contains('[^A-Za-z\s]')]
# Out:
#               director  id
# 18         KÃ¡tia Lund  18
# 33      Ãric Toledano  33
# 45      Chan-wook Park  45
# 62  Jean-Pierre Jeunet  62

# %%
# check if similar directors already exist in table
directors[directors['director'].str.contains('Lund|Toledano', regex=True)]
# Out:
#           director  id
# 18     KÃ¡tia Lund  18
# 33  Ãric Toledano  33

# %%
movie_director['directors'] = movie_director['directors'].apply(lambda x: directors[directors['director'] == x]['id'].values[0])
movie_director.rename(columns={'directors': 'director_id'})
movie_director
# Out:
#      movie_id  directors
# 0           0          0
# 1           1          1
# 2           2          2
# 3           3          1
# 4           4          3
# ..        ...        ...
# 96         96         66
# 97         97         67
# 98         98          9
# 99         99         68
# 100       100         69
#
# [108 rows x 2 columns]

# %%
# edit directors
# directors.iloc[18, 'director'] = 'Kátia Lund'
# directors.iloc[33, 'director'] = 'Éric Toledano'
directors.loc[directors['id'] == 18, 'director'] = 'Kátia Lund'
directors.loc[directors['id'] == 33, 'director'] = 'Éric Toledano'
directors[directors['director'].str.contains('[^A-Za-z\s]')]
# Out:
#               director  id
# 18          Kátia Lund  18
# 33       Éric Toledano  33
# 45      Chan-wook Park  45
# 62  Jean-Pierre Jeunet  62
